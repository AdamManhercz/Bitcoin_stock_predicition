# %% [markdown]
# # Summary

# %%
val_df
# Out:
#      Model          RMSE      MAPE
# 0    ARIMA   3161.114912  0.053000
# 1  Prophet  26102.748391  0.479881
# 2     LSTM   2964.167765  0.052911
# 3  XGBoost   2595.000590  0.043397

# %%
plt.figure(figsize=(10,5))

plt.title("Final forecast for the next 50 days", pad=15)
plt.xlabel("Date")
plt.ylabel("Stock price")

plt.plot(df.index, data, label="Real")
final_pred.plot(label="ARIMA pred")
final_pred_p["Close"].plot(label="Prophet pred")
plt.plot(lstm_dates, final_pred_lstm, label="LSTM pred")
plt.plot(pred_dates, final_pred_xgb, label="XGBoost")

plt.legend()

plt.show()

# %%
plt.figure(figsize=(10,5))

plt.title("Final forecast for the next 50 days", pad=15)
plt.xlabel("Date")
plt.ylabel("Stock price")

final_pred.plot(label="ARIMA pred", color="darkorange")
final_pred_p["Close"].plot(label="Prophet pred", color="g")
plt.plot(lstm_dates, final_pred_lstm, label="LSTM pred", color="r")
plt.plot(pred_dates, final_pred_xgb, label="XGBoost", color="purple")

plt.legend()

plt.show()
